# %% [markdown]
# <a href="https://colab.research.google.com/github/GENRATECODE/Sparks_projct/blob/main/Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# Cloning into 'Sparks_projct'...
# remote: Enumerating objects: 34, done.
# remote: Counting objects: 100% (34/34), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 34 (delta 6), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (34/34), 326.90 KiB | 2.79 MiB/s, done.
